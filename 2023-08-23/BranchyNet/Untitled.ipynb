# %%
from models.Branchynet import Branchynet, ConvPoolAc

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset
import torchvision
import torchvision.transforms as transforms
import matplotlib

import os
import numpy as np
from datetime import datetime as dt

# %%
model = Branchynet()

print(model.parameters)
print()
print(model.backbone.parameters)
print()
print(model.exits[-1].parameters)
# Out:
# <bound method Module.parameters of Branchynet(
#   (backbone): ModuleList(
#     (0): ConvPoolAc(
#       (layer): Sequential(
#         (0): Conv2d(1, 5, kernel_size=(5, 5), stride=(1, 1), padding=(4, 4), bias=False)
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (1): Sequential(
#       (0): ConvPoolAc(
#         (layer): Sequential(
#           (0): Conv2d(5, 10, kernel_size=(5, 5), stride=(1, 1), padding=(4, 4), bias=False)
#           (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (1): ConvPoolAc(
#         (layer): Sequential(
#           (0): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1), padding=(3, 3), bias=False)
#           (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (2): Flatten(start_dim=1, end_dim=-1)
#       (3): Linear(in_features=720, out_features=84, bias=True)
#     )
#   )
#   (exits): ModuleList(
#     (0): Sequential(
#       (0): ConvPoolAc(
#         (layer): Sequential(
#           (0): Conv2d(5, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (2): ReLU(inplace=True)
#         )
#       )
#       (1): Flatten(start_dim=1, end_dim=-1)
#       (2): Linear(in_features=640, out_features=10, bias=True)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=84, out_features=10, bias=True)
#     )
#   )
# )>
#
# <bound method Module.parameters of ModuleList(
#   (0): ConvPoolAc(
#     (layer): Sequential(
#       (0): Conv2d(1, 5, kernel_size=(5, 5), stride=(1, 1), padding=(4, 4), bias=False)
#       (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (2): ReLU(inplace=True)
#     )
#   )
#   (1): Sequential(
#     (0): ConvPoolAc(
#       (layer): Sequential(
#         (0): Conv2d(5, 10, kernel_size=(5, 5), stride=(1, 1), padding=(4, 4), bias=False)
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (1): ConvPoolAc(
#       (layer): Sequential(
#         (0): Conv2d(10, 20, kernel_size=(5, 5), stride=(1, 1), padding=(3, 3), bias=False)
#         (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (2): Flatten(start_dim=1, end_dim=-1)
#     (3): Linear(in_features=720, out_features=84, bias=True)
#   )
# )>
#
# <bound method Module.parameters of Sequential(
#   (0): Linear(in_features=84, out_features=10, bias=True)
# )>
