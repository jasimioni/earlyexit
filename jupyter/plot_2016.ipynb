# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import pickle
import scipy
import sys

from functions import *

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib.ticker import MaxNLocator
from matplotlib import cm

# %%
min_acceptance = 0.7
network = 'alexnet'
best_score, best_accuracy, best_time = get_best_parameters(network, min_acceptance)
plot(network, *best_accuracy[4:], title=f'Results {network} - min_acceptance: {min_acceptance}', years=[2016])
# Out:
# e1: Accuracy: 89.55% - Acceptance: 100% - Cost: 0.61us
# e2: Accuracy: 90.26% - Acceptance: 100% - Cost: 1.54us
#
# Score => Accuracy : Acceptance : Cost	n_e1 : a_e1 : n_e2 : a_e2
# Melhor score:
# 99: 96.52% => 89.55% : 100.00% : 0.61us	0.5000 : 0.5000 : 0.9602 : 0.5419
#
# Melhor accuracy (com acceptance > 85%):
# 99: 71.90% => 94.35% : 70.84% : 1.07us	0.8793 : 0.9806 : 0.9242 : 0.9236
#
# Melhor tempo (com acceptance > 85%):
# 99: 96.52% => 89.55% : 100.00% : 0.61us	0.5000 : 0.5000 : 0.9602 : 0.5419
# (0.8793255142280675, 0.9806389757257812, 0.9241843802268372, 0.9235752258450933)
# /home/jasimioni/ppgia/earlyexit/jupyter/functions.py:116: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=90)

# %%
min_acceptance = 0.8
network = 'alexnet'
best_score, best_accuracy, best_time = get_best_parameters(network, min_acceptance)
plot(network, *best_accuracy[4:], title=f'Results {network} - min_acceptance: {min_acceptance}', years=[2016])
# Out:
# e1: Accuracy: 89.55% - Acceptance: 100% - Cost: 0.61us
# e2: Accuracy: 90.26% - Acceptance: 100% - Cost: 1.54us
#
# Score => Accuracy : Acceptance : Cost	n_e1 : a_e1 : n_e2 : a_e2
# Melhor score:
# 99: 96.52% => 89.55% : 100.00% : 0.61us	0.5000 : 0.5000 : 0.9602 : 0.5419
#
# Melhor accuracy (com acceptance > 85%):
# 99: 77.09% => 93.94% : 82.27% : 1.03us	0.8793 : 0.9651 : 0.9821 : 0.8887
#
# Melhor tempo (com acceptance > 85%):
# 99: 96.52% => 89.55% : 100.00% : 0.61us	0.5000 : 0.5000 : 0.9602 : 0.5419
# (0.8792955896989245, 0.9651289273550562, 0.9821496199690706, 0.888687372657678)
# /home/jasimioni/ppgia/earlyexit/jupyter/functions.py:116: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=90)

# %%
min_acceptance = 0.9
network = 'alexnet'
best_score, best_accuracy, best_time = get_best_parameters(network, min_acceptance)
plot(network, *best_accuracy[4:], title=f'Results {network} - min_acceptance: {min_acceptance}', years=[2016])
# Out:
# e1: Accuracy: 89.55% - Acceptance: 100% - Cost: 0.61us
# e2: Accuracy: 90.26% - Acceptance: 100% - Cost: 1.54us
#
# Score => Accuracy : Acceptance : Cost	n_e1 : a_e1 : n_e2 : a_e2
# Melhor score:
# 99: 96.52% => 89.55% : 100.00% : 0.61us	0.5000 : 0.5000 : 0.9602 : 0.5419
#
# Melhor accuracy (com acceptance > 85%):
# 99: 87.14% => 92.68% : 90.97% : 0.82us	0.8793 : 0.7901 : 0.9228 : 0.9166
#
# Melhor tempo (com acceptance > 85%):
# 99: 96.52% => 89.55% : 100.00% : 0.61us	0.5000 : 0.5000 : 0.9602 : 0.5419
# (0.8792955896989245, 0.7901410669790676, 0.9228124404680417, 0.916601238038309)
# /home/jasimioni/ppgia/earlyexit/jupyter/functions.py:116: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=90)

# %%
min_acceptance = 0.7
network = 'mobilenet'
best_score, best_accuracy, best_time = get_best_parameters(network, min_acceptance)
plot(network, *best_accuracy[4:], title=f'Results {network} - min_acceptance: {min_acceptance}', years=[2016])
# Out:
# e1: Accuracy: 89.60% - Acceptance: 100% - Cost: 2.27us
# e2: Accuracy: 90.08% - Acceptance: 100% - Cost: 9.28us
#
# Score => Accuracy : Acceptance : Cost	n_e1 : a_e1 : n_e2 : a_e2
# Melhor score:
# 99: 96.53% => 89.60% : 100.00% : 2.27us	0.5000 : 0.5000 : 0.8035 : 0.9362
#
# Melhor accuracy (com acceptance > 85%):
# 99: 72.58% => 94.13% : 76.86% : 6.00us	0.8316 : 1.0000 : 0.8819 : 0.9309
#
# Melhor tempo (com acceptance > 85%):
# 99: 96.53% => 89.60% : 100.00% : 2.27us	0.5000 : 0.5000 : 0.8035 : 0.9362
# (0.8315579252331986, 0.9999569566315943, 0.8819188610363026, 0.9308507134005195)
# /home/jasimioni/ppgia/earlyexit/jupyter/functions.py:116: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=90)

# %%
min_acceptance = 0.8
network = 'mobilenet'
best_score, best_accuracy, best_time = get_best_parameters(network, min_acceptance)
plot(network, *best_accuracy[4:], title=f'Results {network} - min_acceptance: {min_acceptance}', years=[2016])
# Out:
# e1: Accuracy: 89.60% - Acceptance: 100% - Cost: 2.27us
# e2: Accuracy: 90.08% - Acceptance: 100% - Cost: 9.28us
#
# Score => Accuracy : Acceptance : Cost	n_e1 : a_e1 : n_e2 : a_e2
# Melhor score:
# 99: 96.53% => 89.60% : 100.00% : 2.27us	0.5000 : 0.5000 : 0.8035 : 0.9362
#
# Melhor accuracy (com acceptance > 85%):
# 99: 77.04% => 93.87% : 82.31% : 5.43us	0.8317 : 0.9860 : 0.8911 : 0.9143
#
# Melhor tempo (com acceptance > 85%):
# 99: 96.53% => 89.60% : 100.00% : 2.27us	0.5000 : 0.5000 : 0.8035 : 0.9362
# (0.8316944585638926, 0.9860160536167408, 0.8910514183290185, 0.9143256100528574)
# /home/jasimioni/ppgia/earlyexit/jupyter/functions.py:116: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=90)

# %%
min_acceptance = 0.9
network = 'mobilenet'
best_score, best_accuracy, best_time = get_best_parameters(network, min_acceptance)
plot(network, *best_accuracy[4:], title=f'Results {network} - min_acceptance: {min_acceptance}', years=[2016])
# Out:
# e1: Accuracy: 89.60% - Acceptance: 100% - Cost: 2.27us
# e2: Accuracy: 90.08% - Acceptance: 100% - Cost: 9.28us
#
# Score => Accuracy : Acceptance : Cost	n_e1 : a_e1 : n_e2 : a_e2
# Melhor score:
# 99: 96.53% => 89.60% : 100.00% : 2.27us	0.5000 : 0.5000 : 0.8035 : 0.9362
#
# Melhor accuracy (com acceptance > 85%):
# 99: 82.99% => 93.41% : 90.22% : 4.70us	0.8316 : 0.9709 : 0.8780 : 0.8551
#
# Melhor tempo (com acceptance > 85%):
# 99: 96.53% => 89.60% : 100.00% : 2.27us	0.5000 : 0.5000 : 0.8035 : 0.9362
# (0.8315567090011495, 0.9708725521529218, 0.8780326694397623, 0.8550573867108003)
# /home/jasimioni/ppgia/earlyexit/jupyter/functions.py:116: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.autofmt_xdate(rotation=90)
